# %%
import pandas as pd

# %%
df = pd.read_csv('UCI_Credit_Card.csv')

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null float64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null float64
# BILL_AMT2                     30000 non-null float64
# BILL_AMT3                     30000 non-null float64
# BILL_AMT4                     30000 non-null float64
# ...

# %%
df.LIMIT_BAL >= 50000
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 29995     True
# 29996     True
# 29997    False
# 29998     True
# 29999     True
# Name: LIMIT_BAL, Length: 30000, dtype: bool

# %%
df.LIMIT_BAL <= 100000
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 29995    False
# 29996    False
# 29997     True
# 29998     True
# 29999     True
# Name: LIMIT_BAL, Length: 30000, dtype: bool

# %%
df[df.LIMIT_BAL >= 50000]
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# 5          6    50000.0    1          1         2   37      0      0      0
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29994  29995    80000.0    1          2         2   34      2      2      2
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
df[df.LIMIT_BAL <= 100000]
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# 5          6    50000.0    1          1         2   37      0      0      0
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29993  29994   100000.0    1          1         2   38      0     -1     -1
# 29994  29995    80000.0    1          2         2   34      2      2      2
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
df.AGE
# Out:
# 0        24
# 1        26
# 2        34
# 3        37
# 4        57
#          ..
# 29995    39
# 29996    43
# 29997    37
# 29998    41
# 29999    46
# Name: AGE, Length: 30000, dtype: int64

# %%
df[df.AGE > 30]
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# 5          6    50000.0    1          1         2   37      0      0      0
# 9         10    20000.0    1          3         2   35     -2     -2     -2
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
df.BILL_AMT4
# Out:
# 0            0.0
# 1         3272.0
# 2        14331.0
# 3        28314.0
# 4        20940.0
#           ...
# 29995    88004.0
# 29996     8979.0
# 29997    20878.0
# 29998    52774.0
# 29999    36535.0
# Name: BILL_AMT4, Length: 30000, dtype: float64

# %%
df[df.BILL_AMT4 > 1000]
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# 5          6    50000.0    1          1         2   37      0      0      0
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
df[df.PAY_3 > 0]
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 8          9   140000.0    2          3         1   28      0      0      2
# 10        11   200000.0    2          3         2   34      0      0      2
# 13        14    70000.0    1          2         2   30      1      2      2
# 16        17    20000.0    1          1         2   24      0      0      2
# 39        40   280000.0    1          1         2   31     -1     -1      2
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29976  29977    40000.0    1          2         2   47      2      2      3
# 29981  29982    50000.0    1          2         1   44      1      2      2
# 29991  29992   210000.0    1          2         1   34      3      2      2
# 29994  29995    80000.0    1          2         2   34      2      2      2
# 29997  29998    30000.0    1          2         2   37      4      3      2
#
# ...

# %%
df[df.PAY_2 < 0]
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 7          8   100000.0    2          2         2   23      0     -1     -1
# 9         10    20000.0    1          3         2   35     -2     -2     -2
# 11        12   260000.0    2          1         2   51     -1     -1     -1
# 18        19   360000.0    2          1         1   49      1     -2     -2
# 19        20   180000.0    2          1         2   29      1     -2     -2
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29986  29987   360000.0    1          1         2   35     -1     -1     -2
# 29989  29990   150000.0    1          1         2   35     -1     -1     -1
# 29993  29994   100000.0    1          1         2   38      0     -1     -1
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29998  29999    80000.0    1          3         1   41      1     -1      0
#
# ...

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('weather.csv')

# %%
df
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0     2013-12-21         74        60        45            67           49
# 1     2013-12-22         56        48        39            43           36
# 2     2013-12-23         58        45        32            31           27
# 3     2013-12-24         61        46        31            36           28
# 4     2013-12-25         58        50        41            44           40
# ...          ...        ...       ...       ...           ...          ...
# 1314  2017-07-27        103        89        75            71           67
# 1315  2017-07-28        105        91        76            71           64
# 1316  2017-07-29        107        92        77            72           64
# 1317  2017-07-30        106        93        79            70           68
# 1318  2017-07-31         99        88        77            66           61
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 21 columns):
# Date                          1319 non-null object
# TempHighF                     1319 non-null int64
# TempAvgF                      1319 non-null int64
# TempLowF                      1319 non-null int64
# DewPointHighF                 1319 non-null object
# DewPointAvgF                  1319 non-null object
# DewPointLowF                  1319 non-null object
# HumidityHighPercent           1319 non-null object
# HumidityAvgPercent            1319 non-null object
# HumidityLowPercent            1319 non-null object
# SeaLevelPressureHighInches    1319 non-null object
# SeaLevelPressureAvgInches     1319 non-null object
# SeaLevelPressureLowInches     1319 non-null object
# VisibilityHighMiles           1319 non-null object
# VisibilityAvgMiles            1319 non-null object
# VisibilityLowMiles            1319 non-null object
# ...

# %%
df.shape
# Out:
# (1319, 21)

# %%
df.head()
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
# ...

# %%
df.tail(10)
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 1309  2017-07-22        103        90        77            74           68
# 1310  2017-07-23        103        90        77            74           71
# 1311  2017-07-24        102        89        76            75           71
# 1312  2017-07-25        103        91        78            75           71
# 1313  2017-07-26        103        91        78            75           70
# 1314  2017-07-27        103        89        75            71           67
# 1315  2017-07-28        105        91        76            71           64
# 1316  2017-07-29        107        92        77            72           64
# 1317  2017-07-30        106        93        79            70           68
# 1318  2017-07-31         99        88        77            66           61
#
#      DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  \
# ...

# %%
df.HumidityHighPercent == 91
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1314    False
# 1315    False
# 1316    False
# 1317    False
# 1318    False
# Name: HumidityHighPercent, Length: 1319, dtype: bool

# %%
df[df.HumidityHighPercent == 91]
# Out:
# Empty DataFrame
# Columns: [Date, TempHighF, TempAvgF, TempLowF, DewPointHighF, DewPointAvgF, DewPointLowF, HumidityHighPercent, HumidityAvgPercent, HumidityLowPercent, SeaLevelPressureHighInches, SeaLevelPressureAvgInches, SeaLevelPressureLowInches, VisibilityHighMiles, VisibilityAvgMiles, VisibilityLowMiles, WindHighMPH, WindAvgMPH, WindGustMPH, PrecipitationSumInches, Events]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.HumidityHighPercent <= '80'
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1314    False
# 1315    False
# 1316    False
# 1317     True
# 1318     True
# Name: HumidityHighPercent, Length: 1319, dtype: bool

# %%
df[df.HumidityHighPercent <= '80']
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 2     2013-12-23         58        45        32            31           27
# 5     2013-12-26         57        48        39            39           36
# 9     2013-12-30         44        40        35            31           26
# 10    2013-12-31         55        46        36            31           28
# 13    2014-01-03         58        43        28            37           22
# ...          ...        ...       ...       ...           ...          ...
# 1284  2017-06-27         91        81        71            74           72
# 1302  2017-07-15        103        87        71            73           70
# 1303  2017-07-16         99        84        68            71           69
# 1317  2017-07-30        106        93        79            70           68
# 1318  2017-07-31         99        88        77            66           61
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = df[['TempHighF','TempAvgF','TempLowF','HumidityAvgPercent','SeaLevelPressureAvgInches','VisibilityAvgMiles','WindAvgMPH']]

# %%
plt.figure(figsize=(16,8))
sns.heatmap(df.corr(), cmap='Blues', annot=True)

# %%
from math import sqrt
from scipy import stats

# %%
df1.head()
# Out:
#    TempHighF  TempAvgF  TempLowF HumidityAvgPercent SeaLevelPressureAvgInches  \
# 0         74        60        45                 75                     29.68
# 1         56        48        39                 68                     30.13
# 2         58        45        32                 52                     30.49
# 3         61        46        31                 56                     30.45
# 4         58        50        41                 71                     30.33
#
#   VisibilityAvgMiles WindAvgMPH
# 0                  7          4
# 1                 10          6
# 2                 10          3
# 3                 10          4
# 4                 10          2

# %%
df.head()
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
# ...

# %%
alpha = 0.01
r, p = stats.pearsonr(df.TempHighF, df.TempLowF)
r, p
# Out:
# (0.8819769159731726, 0.0)

# %%
df[df.HumidityHighPercent <= '70']
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 16    2014-01-06         36        29        22            15            8
# 17    2014-01-07         48        35        22            29           11
# 24    2014-01-14         76        57        37            31           25
# 25    2014-01-15         64        52        40            29           23
# 26    2014-01-16         72        56        40            31           27
# ...          ...        ...       ...       ...           ...          ...
# 1284  2017-06-27         91        81        71            74           72
# 1302  2017-07-15        103        87        71            73           70
# 1303  2017-07-16         99        84        68            71           69
# 1317  2017-07-30        106        93        79            70           68
# 1318  2017-07-31         99        88        77            66           61
#
# ...

# %%
df[df.HumidityHighPercent <= '60']
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 16    2014-01-06         36        29        22            15            8
# 25    2014-01-15         64        52        40            29           23
# 26    2014-01-16         72        56        40            31           27
# 27    2014-01-17         64        54        43            31           20
# 28    2014-01-18         70        54        37            41           33
# ...          ...        ...       ...       ...           ...          ...
# 1262  2017-06-05         90        78        66            70           68
# 1283  2017-06-26         91        82        72            74           72
# 1284  2017-06-27         91        81        71            74           72
# 1302  2017-07-15        103        87        71            73           70
# 1303  2017-07-16         99        84        68            71           69
#
# ...

# %%
df[df.HumidityHighPercent <= '50']
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 16    2014-01-06         36        29        22            15            8
# 25    2014-01-15         64        52        40            29           23
# 27    2014-01-17         64        54        43            31           20
# 91    2014-03-22         77        69        61            65           62
# 96    2014-03-27         82        72        61            68           63
# ...          ...        ...       ...       ...           ...          ...
# 1262  2017-06-05         90        78        66            70           68
# 1283  2017-06-26         91        82        72            74           72
# 1284  2017-06-27         91        81        71            74           72
# 1302  2017-07-15        103        87        71            73           70
# 1303  2017-07-16         99        84        68            71           69
#
# ...

# %%
df2 = df[df.HumidityHighPercent <= '40']

# %%
df2.head()
# Out:
#            Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 91   2014-03-22         77        69        61            65           62
# 96   2014-03-27         82        72        61            68           63
# 134  2014-05-04         91        76        61            42           37
# 176  2014-06-15         91        83        74             -            -
# 197  2014-07-06         95        84        72            73           70
#
#     DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  \
# 91            51                 100                 80                 60
# 96            56                 100                 78                 55
# 134           32                  37                 27                 16
# 176            -                   -                  -                  -
# 197           66                 100                 72                 44
#
#      ... SeaLevelPressureAvgInches SeaLevelPressureLowInches  \
# ...

# %%
df.shape
# Out:
# (1319, 21)

# %%
sns.relplot(x="TempAvgF", y="DewPointAvgF", data=df2);

# %%
sns.relplot(x="TempAvgF", y="DewPointAvgF",hue="HumidityAvgPercent", data=df);

# %%
df2.tail()
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 1262  2017-06-05         90        78        66            70           68
# 1283  2017-06-26         91        82        72            74           72
# 1284  2017-06-27         91        81        71            74           72
# 1302  2017-07-15        103        87        71            73           70
# 1303  2017-07-16         99        84        68            71           69
#
#      DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  \
# 1262           65                 100                 72                 44
# 1283           67                 100                 74                 47
# 1284           67                 100                 75                 50
# 1302           63                 100                 65                 29
# 1303           65                 100                 67                 33
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 21 columns):
# Date                          1319 non-null object
# TempHighF                     1319 non-null int64
# TempAvgF                      1319 non-null int64
# TempLowF                      1319 non-null int64
# DewPointHighF                 1319 non-null object
# DewPointAvgF                  1319 non-null object
# DewPointLowF                  1319 non-null object
# HumidityHighPercent           1319 non-null object
# HumidityAvgPercent            1319 non-null object
# HumidityLowPercent            1319 non-null object
# SeaLevelPressureHighInches    1319 non-null object
# SeaLevelPressureAvgInches     1319 non-null object
# SeaLevelPressureLowInches     1319 non-null object
# VisibilityHighMiles           1319 non-null object
# VisibilityAvgMiles            1319 non-null object
# VisibilityLowMiles            1319 non-null object
# ...

# %%
df2.TempAvgF
# Out:
# 91      69
# 96      72
# 134     76
# 176     83
# 197     84
#         ..
# 1262    78
# 1283    82
# 1284    81
# 1302    87
# 1303    84
# Name: TempAvgF, Length: 225, dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 225 entries, 91 to 1303
# Data columns (total 21 columns):
# Date                          225 non-null object
# TempHighF                     225 non-null int64
# TempAvgF                      225 non-null int64
# TempLowF                      225 non-null int64
# DewPointHighF                 225 non-null object
# DewPointAvgF                  225 non-null object
# DewPointLowF                  225 non-null object
# HumidityHighPercent           225 non-null object
# HumidityAvgPercent            225 non-null object
# HumidityLowPercent            225 non-null object
# SeaLevelPressureHighInches    225 non-null object
# SeaLevelPressureAvgInches     225 non-null object
# SeaLevelPressureLowInches     225 non-null object
# VisibilityHighMiles           225 non-null object
# VisibilityAvgMiles            225 non-null object
# VisibilityLowMiles            225 non-null object
# WindHighMPH                   225 non-null object
# ...

# %%
df2.tail()
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 1262  2017-06-05         90        78        66            70           68
# 1283  2017-06-26         91        82        72            74           72
# 1284  2017-06-27         91        81        71            74           72
# 1302  2017-07-15        103        87        71            73           70
# 1303  2017-07-16         99        84        68            71           69
#
#      DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  \
# 1262           65                 100                 72                 44
# 1283           67                 100                 74                 47
# 1284           67                 100                 75                 50
# 1302           63                 100                 65                 29
# 1303           65                 100                 67                 33
#
# ...

# %%
df3 = df2.tail()

# %%
df3.head()
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 1262  2017-06-05         90        78        66            70           68
# 1283  2017-06-26         91        82        72            74           72
# 1284  2017-06-27         91        81        71            74           72
# 1302  2017-07-15        103        87        71            73           70
# 1303  2017-07-16         99        84        68            71           69
#
#      DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  \
# 1262           65                 100                 72                 44
# 1283           67                 100                 74                 47
# 1284           67                 100                 75                 50
# 1302           63                 100                 65                 29
# 1303           65                 100                 67                 33
#
# ...

# %%
df3.shape
# Out:
# (5, 21)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 1262 to 1303
# Data columns (total 21 columns):
# Date                          5 non-null object
# TempHighF                     5 non-null int64
# TempAvgF                      5 non-null int64
# TempLowF                      5 non-null int64
# DewPointHighF                 5 non-null object
# DewPointAvgF                  5 non-null object
# DewPointLowF                  5 non-null object
# HumidityHighPercent           5 non-null object
# HumidityAvgPercent            5 non-null object
# HumidityLowPercent            5 non-null object
# SeaLevelPressureHighInches    5 non-null object
# SeaLevelPressureAvgInches     5 non-null object
# SeaLevelPressureLowInches     5 non-null object
# VisibilityHighMiles           5 non-null object
# VisibilityAvgMiles            5 non-null object
# VisibilityLowMiles            5 non-null object
# WindHighMPH                   5 non-null object
# ...

# %%
df3.head(1)
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 1262  2017-06-05         90        78        66            70           68
#
#      DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  \
# 1262           65                 100                 72                 44
#
#       ... SeaLevelPressureAvgInches SeaLevelPressureLowInches  \
# 1262  ...                     29.74                     29.68
#
#      VisibilityHighMiles VisibilityAvgMiles VisibilityLowMiles WindHighMPH  \
# 1262                  10                  9                  0          25
#
#      WindAvgMPH WindGustMPH PrecipitationSumInches                     Events
# 1262          3          41                   1.39  Fog , Rain , Thunderstorm
#
# [1 rows x 21 columns]

# %%
df2.HumidityAvgPercent >= '80'
# Out:
# 91       True
# 96      False
# 134     False
# 176     False
# 197     False
#         ...
# 1262    False
# 1283    False
# 1284    False
# 1302    False
# 1303    False
# Name: HumidityAvgPercent, Length: 225, dtype: bool

# %%
df2[df2.HumidityAvgPercent >= '80']
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 91    2014-03-22         77        69        61            65           62
# 209   2014-07-18         78        75        72            74           71
# 266   2014-09-13         66        63        60            63           60
# 267   2014-09-14         77        71        64            67           64
# 272   2014-09-19         86        80        74            75           74
# ...          ...        ...       ...       ...           ...          ...
# 1157  2017-02-20         70        64        58            59           57
# 1170  2017-03-05         75        66        57            65           60
# 1176  2017-03-11         66        64        61            64           62
# 1178  2017-03-13         70        58        48            52           48
# 1207  2017-04-11         72        67        62            70           65
#
# ...

# %%
df2.tail()
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 1262  2017-06-05         90        78        66            70           68
# 1283  2017-06-26         91        82        72            74           72
# 1284  2017-06-27         91        81        71            74           72
# 1302  2017-07-15        103        87        71            73           70
# 1303  2017-07-16         99        84        68            71           69
#
#      DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  \
# 1262           65                 100                 72                 44
# 1283           67                 100                 74                 47
# 1284           67                 100                 75                 50
# 1302           63                 100                 65                 29
# 1303           65                 100                 67                 33
#
# ...

# %%
df.head(10)
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
# 5  2013-12-26         57        48        39            39           36
# 6  2013-12-27         60        53        45            41           39
# 7  2013-12-28         62        51        40            43           39
# 8  2013-12-29         64        50        36            49           41
# 9  2013-12-30         44        40        35            31           26
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# ...

# %%
df.shape
# Out:
# (1319, 21)

# %%
df.VisibilityLowMiles > '10'
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 1314    False
# 1315    False
# 1316    False
# 1317    False
# 1318    False
# Name: VisibilityLowMiles, Length: 1319, dtype: bool

# %%
df[df.VisibilityLowMiles > '10']
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0     2013-12-21         74        60        45            67           49
# 1     2013-12-22         56        48        39            43           36
# 3     2013-12-24         61        46        31            36           28
# 4     2013-12-25         58        50        41            44           40
# 5     2013-12-26         57        48        39            39           36
# ...          ...        ...       ...       ...           ...          ...
# 1302  2017-07-15        103        87        71            73           70
# 1303  2017-07-16         99        84        68            71           69
# 1310  2017-07-23        103        90        77            74           71
# 1311  2017-07-24        102        89        76            75           71
# 1312  2017-07-25        103        91        78            75           71
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 21 columns):
# Date                          1319 non-null object
# TempHighF                     1319 non-null int64
# TempAvgF                      1319 non-null int64
# TempLowF                      1319 non-null int64
# DewPointHighF                 1319 non-null object
# DewPointAvgF                  1319 non-null object
# DewPointLowF                  1319 non-null object
# HumidityHighPercent           1319 non-null object
# HumidityAvgPercent            1319 non-null object
# HumidityLowPercent            1319 non-null object
# SeaLevelPressureHighInches    1319 non-null object
# SeaLevelPressureAvgInches     1319 non-null object
# SeaLevelPressureLowInches     1319 non-null object
# VisibilityHighMiles           1319 non-null object
# VisibilityAvgMiles            1319 non-null object
# VisibilityLowMiles            1319 non-null object
# ...

# %%
df.VisibilityHighMiles <= '10'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1314    True
# 1315    True
# 1316    True
# 1317    True
# 1318    True
# Name: VisibilityHighMiles, Length: 1319, dtype: bool

# %%
df[df.VisibilityHighMiles <= '10']
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0     2013-12-21         74        60        45            67           49
# 1     2013-12-22         56        48        39            43           36
# 2     2013-12-23         58        45        32            31           27
# 3     2013-12-24         61        46        31            36           28
# 4     2013-12-25         58        50        41            44           40
# ...          ...        ...       ...       ...           ...          ...
# 1314  2017-07-27        103        89        75            71           67
# 1315  2017-07-28        105        91        76            71           64
# 1316  2017-07-29        107        92        77            72           64
# 1317  2017-07-30        106        93        79            70           68
# 1318  2017-07-31         99        88        77            66           61
#
# ...

# %%
df = pd.read_csv('UCI_Credit_Card.csv')

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.tail(5)
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 29995      0  ...    88004.0    31237.0    15980.0    8500.0   20000.0
# 29996     -1  ...     8979.0     5190.0        0.0    1837.0    3526.0
# 29997     -1  ...    20878.0    20582.0    19357.0       0.0       0.0
# 29998      0  ...    52774.0    11855.0    48944.0   85900.0    3409.0
# 29999      0  ...    36535.0    32428.0    15313.0    2078.0    1800.0
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
df.PAY_AMT1 >= 2000
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4         True
#          ...
# 29995     True
# 29996    False
# 29997    False
# 29998     True
# 29999     True
# Name: PAY_AMT1, Length: 30000, dtype: bool

# %%
df[df.PAY_AMT1 >= 2000]
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# 5          6    50000.0    1          1         2   37      0      0      0
# 6          7   500000.0    1          1         2   29      0      0      0
# 8          9   140000.0    2          3         1   28      0      0      2
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29993  29994   100000.0    1          1         2   38      0     -1     -1
# 29994  29995    80000.0    1          2         2   34      2      2      2
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
df[df.PAY_AMT1 >= 100000]
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 463      464   230000.0    2          1         2   28      0      0      0
# 480      481   250000.0    2          2         1   40      0      0      0
# 828      829   200000.0    2          2         1   58     -1     -1     -1
# 1065    1066   270000.0    2          2         1   25      0      0      0
# 1386    1387   360000.0    1          1         2   36     -1     -1     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29666  29667   300000.0    1          3         1   41     -1     -1     -1
# 29820  29821   400000.0    1          2         2   37      1     -1      0
# 29867  29868   340000.0    1          1         2   29     -1      0      0
# 29902  29903   170000.0    1          3         2   30      0     -1      0
# 29963  29964   610000.0    1          1         2   31      0     -1      2
#
# ...

# %%
df[df.PAY_AMT1 >= 500000]
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 12330  12331   300000.0    1          2         1   37      1     -1      2
# 28716  28717   340000.0    2          1         3   42     -1     -1     -1
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1   PAY_AMT2  \
# 12330      0  ...    30355.0    26771.0    23737.0  505000.0      331.0
# 28716     -1  ...   205931.0   265431.0   270237.0  873552.0  1215471.0
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# 12330    1070.0   17771.0   18000.0   16079.0                           0
# 28716  889043.0  621000.0   20000.0  145000.0                           0
#
# [2 rows x 25 columns]

# %%
df.PAY_AMT5 >=20000
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29995    False
# 29996    False
# 29997    False
# 29998     True
# 29999    False
# Name: PAY_AMT5, Length: 30000, dtype: bool

# %%
df.PAY_AMT6 <= 100000
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 29995    True
# 29996    True
# 29997    True
# 29998    True
# 29999    True
# Name: PAY_AMT6, Length: 30000, dtype: bool

# %%
df[df.PAY_AMT5 >=20000 ]
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 17        18   320000.0    1          1         1   49      0      0      0
# 30        31   230000.0    2          1         2   27     -1     -1     -1
# 37        38    60000.0    2          2         2   22      0      0      0
# 40        41   360000.0    1          1         2   33      0      0      0
# 74        75   340000.0    1          1         2   32     -1     -1     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29949  29950   280000.0    1          1         1   39      0      0      0
# 29954  29955   180000.0    1          2         2   30      0      0      0
# 29963  29964   610000.0    1          1         2   31      0     -1      2
# 29972  29973   190000.0    1          1         1   37      0      0      0
# 29998  29999    80000.0    1          3         1   41      1     -1      0
#
# ...

# %%
df = pd.read_csv('advertising.csv')

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.shape
# Out:
# (200, 4)

# %%
plt.figure(figsize=(16,8))
sns.heatmap(df.corr(), cmap='Blues', annot=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
# TV           200 non-null float64
# Radio        200 non-null float64
# Newspaper    200 non-null float64
# Sales        200 non-null float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
# Outlier Analysis
fig, axs = plt.subplots(3, figsize = (5,5))
plt1 = sns.boxplot(df['TV'], ax = axs[0])
plt2 = sns.boxplot(df['Newspaper'], ax = axs[1])
plt3 = sns.boxplot(df['Radio'], ax = axs[2])
plt.tight_layout()

# %%
sns.pairplot(df, x_vars=['TV', 'Newspaper', 'Radio'], y_vars='Sales', height=4, aspect=1, kind='scatter')
plt.show()

# %%
X = df['TV']
y = df['Sales']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
# Let's now take a look at the train dataset
X_train.head()
# Out:
# 74     213.4
# 3      151.5
# 185    205.0
# 26     142.9
# 90     134.3
# Name: TV, dtype: float64

# %%
y_train.head()
# Out:
# 74     17.0
# 3      16.5
# 185    22.6
# 26     15.0
# 90     14.0
# Name: Sales, dtype: float64

# %%
import statsmodels.api as sm

# %%
# Add a constant to get an intercept
X_train_sm = sm.add_constant(X_train)

# Fit the resgression line using 'OLS'
lr = sm.OLS(y_train, X_train_sm).fit()
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
# Print the parameters, i.e. the intercept and the slope of the regression line fitted
lr.params
# Out:
# const    6.948683
# TV       0.054546
# dtype: float64

# %%
# Performing a summary operation lists out all the different parameters of the regression line fitted
print(lr.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.814
# Method:                 Least Squares   F-statistic:                     611.2
# Date:                Mon, 19 Oct 2020   Prob (F-statistic):           1.52e-52
# Time:                        12:40:24   Log-Likelihood:                -321.12
# No. Observations:                 140   AIC:                             646.2
# Df Residuals:                     138   BIC:                             652.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.9487      0.385     18.068      0.000       6.188       7.709
# ...

# %%
plt.scatter(X_train, y_train)
plt.plot(X_train, 6.948 + 0.054*X_train, 'r')
plt.show()

# %%
y_train_pred = lr.predict(X_train_sm)
res = (y_train - y_train_pred)

# %%
fig = plt.figure()
sns.distplot(res, bins = 15)
fig.suptitle('Error Terms', fontsize = 15)                  # Plot heading 
plt.xlabel('y_train - y_train_pred', fontsize = 15)         # X-label
plt.show()

# %%
plt.scatter(X_train,res)
plt.show()

# %%
# Add a constant to X_test
X_test_sm = sm.add_constant(X_test)

# Predict the y values corresponding to X_test_sm
y_pred = lr.predict(X_test_sm)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
y_pred.head()
# Out:
# 126     7.374140
# 104    19.941482
# 99     14.323269
# 92     18.823294
# 111    20.132392
# dtype: float64

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
#Returns the mean squared error; we'll take a square root
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 2.019296008966233

# %%
r_squared = r2_score(y_test, y_pred)
r_squared
# Out:
# 0.7921031601245658

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, 6.948 + 0.054 * X_test, 'r')
plt.show()

# %%
df = pd.read_excel('score.xls')
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'ascii'

# %%
df
# Out:
#     EXAM1  EXAM2  EXAM3  FINAL
# 0      73     80     75    152
# 1      93     88     93    185
# 2      89     91     90    180
# 3      96     98    100    196
# 4      73     66     70    142
# 5      53     46     55    101
# 6      69     74     77    149
# 7      47     56     60    115
# 8      87     79     90    175
# 9      79     70     88    164
# 10     69     70     73    141
# 11     70     65     74    141
# 12     93     95     91    184
# 13     79     80     73    152
# 14     70     73     78    148
# 15     93     89     96    192
# 16     78     75     68    147
# 17     81     90     93    183
# 18     88     92     86    177
# 19     78     83     77    159
# 20     82     86     90    177
# 21     86     82     89    175
# 22     78     83     85    175
# 23     76     83     71    149
# 24     96     93     95    192

# %%
plt.figure(figsize=(16,8))
sns.heatmap(df.corr(), cmap='Blues', annot=True)

# %%
df = pd.read_excel('mlr02.xls')
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'ascii'

# %%
df
# Out:
#      X1  X2   X3
# 0   132  52  173
# 1   143  59  184
# 2   153  67  194
# 3   162  73  211
# 4   154  64  196
# 5   168  74  220
# 6   137  54  188
# 7   149  61  188
# 8   159  65  207
# 9   128  46  167
# 10  166  72  217

# %%
plt.figure(figsize=(16,8))
sns.heatmap(df.corr(), cmap='Blues', annot=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
# X1    11 non-null int64
# X2    11 non-null int64
# X3    11 non-null int64
# dtypes: int64(3)
# memory usage: 392.0 bytes

# %%
df.head()
# Out:
#     X1  X2   X3
# 0  132  52  173
# 1  143  59  184
# 2  153  67  194
# 3  162  73  211
# 4  154  64  196
